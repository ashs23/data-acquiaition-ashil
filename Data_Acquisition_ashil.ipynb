# %%
import numpy as np
import pandas as pd

# %%
df= pd.read_csv('/content/Alzheimer_s_Disease_and_Healthy_Aging_Data.csv')

# %%
print(df.head())
# Out:
#                                      RowId  YearStart  YearEnd LocationAbbr  \
# 0    BRFSS~2022~2022~42~Q03~TMC01~AGE~RACE       2022     2022           PA
# 1    BRFSS~2022~2022~46~Q03~TMC01~AGE~RACE       2022     2022           SD
# 2    BRFSS~2022~2022~16~Q03~TMC01~AGE~RACE       2022     2022           ID
# 3    BRFSS~2022~2022~24~Q03~TMC01~AGE~RACE       2022     2022           MD
# 4  BRFSS~2022~2022~55~Q03~TMC01~AGE~GENDER       2022     2022           WI
#
#    LocationDesc Datasource          Class                     Topic  \
# 0  Pennsylvania      BRFSS  Mental Health  Frequent mental distress
# 1  South Dakota      BRFSS  Mental Health  Frequent mental distress
# 2         Idaho      BRFSS  Mental Health  Frequent mental distress
# 3      Maryland      BRFSS  Mental Health  Frequent mental distress
# 4     Wisconsin      BRFSS  Mental Health  Frequent mental distress
#
#                                             Question Data_Value_Unit  ...  \
# ...

# %%
df.describe()
# Out:
#           YearStart       YearEnd   Data_Value  Data_Value_Alt  \
# count  14790.000000  14790.000000  9909.000000     9909.000000
# mean    2021.987492   2021.987492    43.839288       43.839288
# std        0.256195      0.256195    23.617287       23.617287
# min     2015.000000   2015.000000     2.000000        2.000000
# 25%     2022.000000   2022.000000    25.200000       25.200000
# 50%     2022.000000   2022.000000    41.200000       41.200000
# 75%     2022.000000   2022.000000    65.200000       65.200000
# max     2022.000000   2022.000000    99.100000       99.100000
#
#        Low_Confidence_Limit  High_Confidence_Limit    LocationID
# count           9909.000000            9909.000000  14789.000000
# mean              38.887567              48.893995    307.421597
# std               23.113424              24.081828   1552.811945
# min                1.200000               3.000000      1.000000
# 25%               20.000000              30.100000     17.000000
# ...

# %%
df.shape
# Out:
# (14790, 31)

# %%
df.dtypes
# Out:
# RowId                          object
# YearStart                       int64
# YearEnd                         int64
# LocationAbbr                   object
# LocationDesc                   object
# Datasource                     object
# Class                          object
# Topic                          object
# Question                       object
# Data_Value_Unit                object
# DataValueTypeID                object
# Data_Value_Type                object
# Data_Value                    float64
# Data_Value_Alt                float64
# Data_Value_Footnote_Symbol     object
# Data_Value_Footnote            object
# Low_Confidence_Limit          float64
# High_Confidence_Limit         float64
# StratificationCategory1        object
# Stratification1                object
# StratificationCategory2        object
# Stratification2                object
# Geolocation                    object
# ClassID                        object
# TopicID                        object
# ...

# %%
df.isnull().sum()
# Out:
# RowId                            0
# YearStart                        0
# YearEnd                          0
# LocationAbbr                     0
# LocationDesc                     0
# Datasource                       0
# Class                            0
# Topic                            0
# Question                         0
# Data_Value_Unit                  0
# DataValueTypeID                  0
# Data_Value_Type                  0
# Data_Value                    4881
# Data_Value_Alt                4881
# Data_Value_Footnote_Symbol    9868
# Data_Value_Footnote           9868
# Low_Confidence_Limit          4881
# High_Confidence_Limit         4881
# StratificationCategory1          1
# Stratification1                  1
# StratificationCategory2       1948
# Stratification2               1948
# Geolocation                    623
# ClassID                          1
# TopicID                          1
# QuestionID                       1
# LocationID                       1
# ...

# %%
df.nunique()
# Out:
# RowId                         3342
# YearStart                        7
# YearEnd                          7
# LocationAbbr                    59
# LocationDesc                    59
# Datasource                       1
# Class                            7
# Topic                           33
# Question                        33
# Data_Value_Unit                  2
# DataValueTypeID                  2
# Data_Value_Type                  2
# Data_Value                     919
# Data_Value_Alt                 919
# Data_Value_Footnote_Symbol       4
# Data_Value_Footnote              5
# Low_Confidence_Limit           894
# High_Confidence_Limit          940
# StratificationCategory1          1
# Stratification1                  3
# StratificationCategory2          2
# Stratification2                  7
# Geolocation                     54
# ClassID                          7
# TopicID                         33
# QuestionID                      33
# LocationID                      59
# ...

# %%
mean_price = df['YearStart'].mean()
median_price = df['YearStart'].median()
std_dev_price = df['YearStart'].std()

print(f"Mean YearStart	: {mean_price:.4f}")
print(f"Median YearStart	: {median_price:.4f}")
print(f"Standard Deviation of YearStart	: {std_dev_price:.4f}")
# Out:
# Mean YearStart	: 2021.9875
# Median YearStart	: 2022.0000
# Standard Deviation of YearStart	: 0.2562

# %%
Q1 =df['YearStart'].quantile(0.25)
Q1
# Out:
# 2022.0

# %%
Q3 =df['YearStart'].quantile(0.75)
Q3
# Out:
# 2022.0

# %%
from re import I
IQR = Q3 - Q1
IQR
# Out:
# 0.0

# %%
lower_bound = Q1 - 1.5 * IQR
lower_bound
# Out:
# 2022.0

# %%
upper_bound = Q3 + 1.5 * IQR
upper_bound
# Out:
# 2022.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.boxplot(df['YearStart'])
plt.title(f'Boxplot of YearStart')
plt.show()

# %%
for col in df.columns:
  if df[col].dtype=='object':
    try:
      df[col]=pd.to_numeric(df[col],errors='coerce')
    except valueerror:

        pass

# %%
df.corr()
df
# Out:
#        RowId  YearStart  YearEnd  LocationAbbr  LocationDesc  Datasource  \
# 0        NaN       2022     2022           NaN           NaN         NaN
# 1        NaN       2022     2022           NaN           NaN         NaN
# 2        NaN       2022     2022           NaN           NaN         NaN
# 3        NaN       2022     2022           NaN           NaN         NaN
# 4        NaN       2022     2022           NaN           NaN         NaN
# ...      ...        ...      ...           ...           ...         ...
# 14785    NaN       2022     2022           NaN           NaN         NaN
# 14786    NaN       2022     2022           NaN           NaN         NaN
# 14787    NaN       2022     2022           NaN           NaN         NaN
# 14788    NaN       2022     2022           NaN           NaN         NaN
# 14789    NaN       2022     2022           NaN           NaN         NaN
#
#        Class  Topic  Question  Data_Value_Unit  ...  Stratification2  \
# ...

# %%
grouped_data = df.groupby('YearStart')['YearEnd'].sum()

print("\nGrouped data - sum of 'YearEnd' grouped by 'YearStart':")
print(grouped_data)
# Out:
# Grouped data - sum of 'YearEnd' grouped by 'YearStart':
# YearStart
# 2015       18135
# 2016       10080
# 2017       14119
# 2018       10090
# 2019       20190
# 2021       14147
# 2022    29818434
# Name: YearEnd, dtype: int64

# %%
grouped_data = df.groupby('YearStart')['YearEnd'].median()

print("\nGrouped data - sum of 'YearEnd' grouped by 'YearStart':")
print(grouped_data)
# Out:
# Grouped data - sum of 'YearEnd' grouped by 'YearStart':
# YearStart
# 2015    2015.0
# 2016    2016.0
# 2017    2017.0
# 2018    2018.0
# 2019    2019.0
# 2021    2021.0
# 2022    2022.0
# Name: YearEnd, dtype: float64
